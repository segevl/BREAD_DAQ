# %% [markdown]
# ### BREAD REAL Firmware.
# * Input: ADC D
# * Output: DAC B
# * Data chain: ADC -> PFB -> XFFT -> Accumulator.
#
# See examples to extract data from the different points.

# %%
import sys
sys.path.append('./soft')

from top import *
from helpers import *

import numpy as np

import matplotlib.pyplot as plt
from numpy.fft import fft, fftshift

# %%
# Load bitstream with custom overlay
soc = TopSoc('./bread_real.bit')

# Print information.
print(soc)
# Out:
# BREAD configuration:
#
# 	Board: RFSoC4x2
# 	Analysis 0:
# 		ADC: 224_0, fs = 4915.2 MHz, Decimation    = 2
# 		PFB: fs = 307.2 MHz, fc = 153.6 MHz, 16 channels

# %%
from IPython.display import Image, display
display(Image(filename='images/firmware.png', embed=True))

# %%
#########################
### Define dual chain ###
#########################
chain = DualChain(soc,soc['analysis'][0],soc['synthesis'][0])

# %%
##########################################
### Simple Sine Loop-back (ADC output) ###
##########################################
# Get data.
[xi,xq] = chain.get_data_adc()
x = xi + 1j*xq

# ADU to V.
# 500mV --> 2^15
x = x*0.5/2**15

# Spectrum.
w = np.hanning(len(x))
Aw = len(w)/np.sum(w)
xw = Aw*x*w
Y = fftshift(fft(xw)/len(xw))
F = np.linspace(0,chain.fs,len(Y))

# Normalize to dBm.
R = 50;
Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1,Y1));

plt.figure(1,dpi=150)
plt.plot(F,Y)
plt.plot(F1,Y1,'r*');
plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
plt.xlim([100,2000])
plt.ylim([-120,-30])

# Time domain signal.
n = np.arange(len(x))
t = n/chain.fs
plt.figure(2,dpi=150)
plt.plot(1000*t,np.real(x))
plt.xlabel("t [ns]");
plt.ylabel("Amplitude [mV]");
plt.xlim([0,100]);
# Out:
# F1 = 378.987, Y1 = -19.222

# %%
##########################################
### Simple Sine Loop-back (PFB output) ###
##########################################
fout = 650

# Compute channel center frequency.
FC = chain.analysis.ch2freq(chain.analysis.freq2ch(fout))

# Get data.
[xi,xq] = chain.get_bin_pfb(fout)
x = xi + 1j*xq

# ADU to V.
# 500mV --> 2^15
x = x*0.5/2**15

# Spectrum.
w = np.hanning(len(x))
Aw = len(w)/np.sum(w)
xw = Aw*x*w
Y = fftshift(fft(xw)/len(xw))
F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

# Normalize to dBm.
R = 50;
Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1+FC,Y1));

plt.figure(1,dpi=150)
plt.plot(F+FC,Y)
plt.plot(F1+FC,Y1,'r*');
plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
# Out:
# F1 = 529.290, Y1 = -5.213

# %%
##########################################
### Channels Side-by-Side (PFB output) ###
##########################################
# Channels to plot.
K = np.arange(chain.nch)

plt.figure(1,dpi=150)

# Frequency and amplitude vectors.
FF = []
AA = []
for KK in K:
    print("Iteration K = %d" %KK)  
    # Channel center frequency.
    fck = chain.analysis.ch2freq(KK)
    
    # Get data.
    [xi,xq] = chain.get_bin_pfb(fck+1)
    x = xi + 1j*xq

    # ADU to V.
    # 500mV --> 2^15
    x = x*0.5/2**15

    # Spectrum.
    w = np.hanning(len(x))
    Aw = len(w)/np.sum(w)
    xw = Aw*x*w
    Y = fftshift(fft(xw)/len(xw))
    F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

    # Normalize to dBm.
    R = 50;
    Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));
    
    Fk = F+fck
    plt.plot(Fk,Y)

plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
# Out:
# Iteration K = 0
# Iteration K = 1
# Iteration K = 2
# Iteration K = 3
# Iteration K = 4
# Iteration K = 5
# Iteration K = 6
# Iteration K = 7
# Iteration K = 8
# Iteration K = 9
# Iteration K = 10
# Iteration K = 11
# Iteration K = 12
# Iteration K = 13
# Iteration K = 14
# Iteration K = 15

# %%
###########################################
### Simple Sine Loop-back (XFFT output) ###
###########################################
fout = 1100

# Compute channel center frequency.
FC = chain.analysis.ch2freq(chain.analysis.freq2ch(fout))

# Get data.
[xi,xq] = chain.get_bin_xfft(fout)
x = xi + 1j*xq

# ADU to V.
# 500mV --> 2^15
x = x*0.5/2**15

# Scale by FFT length.
x = x/soc.FFT_N

# Spectrum.
Y = fftshift(x)
F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

# Normalize to dBm.
R = 50;
Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1+FC,Y1));

plt.figure(1,dpi=150)
plt.plot(F+FC,Y)
plt.plot(F1+FC,Y1,'r*');
plt.xlabel("F [MHz]");
# Out:
# F1 = 980.289, Y1 = -15.205

# %%
###########################################
### Channels Side-by-Side (XFFT output) ###
###########################################
# Channels to plot.
K = np.arange(chain.nch)

plt.figure(1,dpi=150)

# Frequency and amplitude vectors.
FF = []
AA = []
for KK in K:
    print("Iteration K = %d" %KK)
    # Channel center frequency.
    fck = chain.analysis.ch2freq(KK)
    
    # Get data.    
    [xi,xq] = chain.get_bin_xfft(fck+1)    
    x = xi + 1j*xq

    # ADU to V.
    # 500mV --> 2^15
    x = x*0.5/2**15
    
    # Scale by FFT length.
    x = x/soc.FFT_N

    # Spectrum.
    Y = fftshift(x)
    F = np.linspace(-chain.fs_ch/2,chain.fs_ch/2,len(Y))

    # Normalize to dBm.
    R = 50;
    Y = 10*np.log10((np.abs(Y)**2)/(2*R*1e-3));
    
    Fk = F+fck
    plt.plot(Fk,Y)

plt.xlabel("F [MHz]");
plt.ylabel("Power [dBm]");
# Out:
# Iteration K = 0
# Iteration K = 1
# Iteration K = 2
# Iteration K = 3
# Iteration K = 4
# Iteration K = 5
# Iteration K = 6
# Iteration K = 7
# Iteration K = 8
# Iteration K = 9
# Iteration K = 10
# Iteration K = 11
# Iteration K = 12
# Iteration K = 13
# Iteration K = 14
# Iteration K = 15

# %%
##########################################
### Simple Sine Loop-back (ACC output) ###
##########################################
# Number of averages.
N = 10

# Get data.
x = chain.get_data_acc(N)

# ADU to V.
# 500mV --> 2^15
x = x*(0.5/2**15)**2

# Scale by FFT length.
x = x/(soc.FFT_N)**2

# Spectrum.
Y = fftshift(x)
F = np.linspace(0,chain.fs,len(Y))

# Normalize to dBm.
R = 50;
Y = 10*np.log10((np.sqrt(Y)**2)/(2*R*1e-3));

# Max.
[F1,Y1] = findPeak(F,Y);
print('F1 = {:.3f}, Y1 = {:.3f}'.format(F1,Y1));

plt.figure(1,dpi=150)
plt.plot(F,Y)
plt.plot(F1,Y1,'r*');
plt.xlabel("F [MHz]");
plt.xlim([100,2000]);
plt.ylim([-120,0]);
# Out:
# F1 = 378.967, Y1 = -2.442

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Get the data (N=1 keeps it cleanest, but you can use more averages)
raw_acc_data = chain.get_data_acc(N=10)

# 2. Create an axis for the bins (just 0 to length)
bins = np.arange(len(raw_acc_data))

# 3. Plot
plt.figure(figsize=(10, 6))
plt.plot(bins, raw_acc_data)
plt.title("Raw Accumulator Output (Integer Power Sums)")
plt.xlabel("Frequency Bin Index")
plt.ylabel("Accumulated Power (ADC Codes²)")
plt.grid(True)
plt.show()

# %%
raw_acc_data = chain.get_data_acc(N=1)

print(len(raw_acc_data))
# Out:
# 262144
